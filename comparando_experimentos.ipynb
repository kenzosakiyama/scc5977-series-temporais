# %% [markdown]
# # Carregando todas as Runs

# %%
from pathlib import Path
from ranx import Run, Qrels

# %%
RUN_FOLDER = "evaluation/runs"
QRELS_PATH = 'evaluation/qrels.json'

# %%
source_folder = Path(RUN_FOLDER)

# %%
runs = []
for f in source_folder.iterdir():
  run = Run.from_file(f, name=f.stem.replace('_', ' ').replace('-', '.').capitalize())
  runs.append(run)

# %%
# ordenar runs por nome
runs.sort(key=lambda x: x.name)

# %%
qrels = Qrels.from_file(QRELS_PATH)

# %% [markdown]
# # Comparação entre Runs

# %%
from ranx import evaluate, compare

# %%
METRICS = ["recall@10", 'map@10', 'hit_rate@10', 'mrr@10']
# METRICS = 'mrr@10'

# %%
report = compare(
    qrels=qrels,
    runs=runs,
    metrics=METRICS,
    max_p=0.05  # P-value threshold
)

# %%
print(report)
# Out:
# #    Model                    Recall@10        MAP@10           Hit Rate@10    MRR@10
# ---  -----------------------  ---------------  ---------------  -------------  ---------------
# a    Adtw multivar            0.241ᵉ           0.196ᵉ           0.965ᵉ         0.807ᵉ
# b    Adtw useracceleration.x  0.257ᵈᵉʰ         0.216ᵈᵉʰ         0.993ᵉ         0.837ᵉ
# c    Adtw useracceleration.y  0.277ᵃᵇᵈᵉᶠʰᶦ     0.241ᵃᵇᵈᵉᶠʰˡ     0.993ᵉ         0.861ᵈᵉʰ
# d    Adtw useracceleration.z  0.227ᵉ           0.178ᵉ           0.979ᵉ         0.788ᵉ
# e    Ddtw multivar            0.186            0.151            0.903          0.713
# f    Ddtw useracceleration.x  0.257ᵈᵉʰ         0.216ᵈᵉʰ         0.993ᵉ         0.837ᵉ
# g    Ddtw useracceleration.y  0.277ᵃᵇᵈᵉᶠʰᶦ     0.241ᵃᵇᵈᵉᶠʰˡ     0.993ᵉ         0.861ᵈᵉʰ
# h    Ddtw useracceleration.z  0.227ᵉ           0.178ᵉ           0.979ᵉ         0.788ᵉ
# i    Dtw multivar             0.254ᵈᵉʰ         0.231ᵃᵈᵉʰ        0.986ᵉ         0.917ᵃᵇᶜᵈᵉᶠᵍʰˡ
# j    Dtw useracceleration.x   0.283ᵃᵇᵈᵉᶠʰᶦˡ    0.253ᵃᵇᵈᵉᶠʰˡ     0.993ᵉ         0.874ᵃᵈᵉʰ
# k    Dtw useracceleration.y   0.297ᵃᵇᶜᵈᵉᶠᵍʰᶦˡ  0.267ᵃᵇᶜᵈᵉᶠᵍʰᶦˡ  1.000ᵃᵉ        0.926ᵃᵇᶜᵈᵉᶠᵍʰʲˡ
# l    Dtw useracceleration.z   0.258ᵈᵉʰ         0.218ᵈᵉʰ         0.993ᵃᵉ        0.871ᵃᵈᵉʰ
