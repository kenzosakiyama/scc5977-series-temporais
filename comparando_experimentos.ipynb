# %% [markdown]
# # Carregando todas as Runs

# %%
from pathlib import Path
from ranx import Run, Qrels

# %%
RUN_FOLDER = "evaluation/runs"
QRELS_PATH = 'evaluation/qrels.json'

# %%
source_folder = Path(RUN_FOLDER)

# %%
runs = []
for f in source_folder.iterdir():
  run = Run.from_file(f, name=f.stem.replace('_', ' ').replace('-', '.').capitalize())
  runs.append(run)

# %%
qrels = Qrels.from_file(QRELS_PATH)

# %% [markdown]
# # Comparação entre Runs

# %%
from ranx import evaluate, compare

# %%
METRICS = ["recall@10", 'map@10', 'hit_rate@10', 'mrr@10']
# METRICS = 'mrr@10'

# %%
report = compare(
    qrels=qrels,
    runs=runs,
    metrics=METRICS,
    max_p=0.05  # P-value threshold
)

# %%
print(report)
# Out:
# #    Model                    Recall@10     MAP@10        Hit Rate@10    MRR@10
# ---  -----------------------  ------------  ------------  -------------  ------------
# a    Adtw useracceleration.y  0.277ᵇᶜᵈᵍʰ    0.241ᵇᶜᶠᵍʰ    0.993ʰ         0.861ᶜʰ
# b    Adtw multivar            0.241ʰ        0.196ʰ        0.965ʰ         0.807ʰ
# c    Adtw useracceleration.z  0.227ʰ        0.178ʰ        0.979ʰ         0.788ʰ
# d    Dtw multivar             0.254ᶜʰ       0.231ᵇᶜʰ      0.986ʰ         0.917ᵃᵇᶜᶠᵍʰ
# e    Dtw useracceleration.y   0.297ᵃᵇᶜᵈᶠᵍʰ  0.267ᵃᵇᶜᵈᶠᵍʰ  1.000ᵇʰ        0.926ᵃᵇᶜᶠᵍʰᶦ
# f    Dtw useracceleration.z   0.258ᶜʰ       0.218ᶜʰ       0.993ᵇʰ        0.871ᵇᶜʰ
# g    Adtw useracceleration.x  0.257ᶜʰ       0.216ᶜʰ       0.993ʰ         0.837ʰ
# h    Ddtw multivar            0.186         0.151         0.903          0.713
# i    Dtw useracceleration.x   0.283ᵇᶜᵈᶠᵍʰ   0.253ᵇᶜᶠᵍʰ    0.993ʰ         0.874ᵇᶜʰ
